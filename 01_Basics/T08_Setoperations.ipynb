# %%
###Set Operations Challenge###

# %%
python_students = {"Rahul", "Aman", "Priya", "Karan", "Neha"}

java_students = {"Priya", "Karan", "Rohit", "Simran"}

# %%
#Print both sets
print("Python Students:", python_students)
print("Java Students:", java_students)
# Out:
# Python Students: {'Priya', 'Neha', 'Aman', 'Karan', 'Rahul'}
# Java Students: {'Priya', 'Simran', 'Karan', 'Rohit'}

# %%
#Students learning either Python OR Java
all_students = python_students.union(java_students)
print("Python or Java Students:", all_students)
# Out:
# Python or Java Students: {'Neha', 'Karan', 'Priya', 'Aman', 'Simran', 'Rahul', 'Rohit'}

# %%
#Students learning BOTH Python and Java
both_students = python_students.intersection(java_students)
print("Students learning both:", both_students)
# Out:
# Students learning both: {'Priya', 'Karan'}

# %%
#Students learning ONLY Python
only_python = python_students.difference(java_students)
print("Only Python:", only_python)
# Out:
# Only Python: {'Neha', 'Aman', 'Rahul'}

# %%
#Students learning ONLY Java
only_java = java_students.difference(python_students)
print("Only Java:", only_java)
# Out:
# Only Java: {'Simran', 'Rohit'}

# %%
#Students belonging to exactly ONE group
one_group = python_students.symmetric_difference(java_students)
print("Exactly one group:", one_group)
# Out:
# Exactly one group: {'Neha', 'Aman', 'Simran', 'Rahul', 'Rohit'}

# %%
#Add a new student
python_students.add("Amrutha")
print("After adding Amrutha:", python_students)
# Out:
# After adding Amrutha: {'Priya', 'Neha', 'Aman', 'Karan', 'Amrutha', 'Rahul'}

# %%
#Remove a student
python_students.remove("Rahul")
print("After removing Rahul:", python_students)
# Out:
# After removing Rahul: {'Priya', 'Neha', 'Aman', 'Karan', 'Amrutha'}

# %%
#Demonstrate discard()
java_students.discard("Rohit")
print("After discarding Rohit:", java_students)
# Out:
# After discarding Rohit: {'Priya', 'Simran', 'Karan'}
