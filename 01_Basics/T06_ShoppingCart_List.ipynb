# %%
###Shopping Cart Using a Python List###

# %%
cart = ["Laptop", "Mouse", "Keyboard", "Monitor", "Headphones"]

# %%
#Display all products
print("Cart Contents:", cart)
# Out:
# Cart Contents: ['Laptop', 'Mouse', 'Keyboard', 'Monitor', 'Headphones']

# %%
# Access first and last products
print("First product:", cart[0])
print("Last product:", cart[-1])
# Out:
# First product: Laptop
# Last product: Headphones

# %%
#Add "Webcam"
cart.append("Webcam")
print("Updated List:", cart)
# Out:
# Updated List: ['Laptop', 'Mouse', 'Keyboard', 'Monitor', 'Headphones', 'Webcam']

# %%
#Insert "USB Hub" at index 2
cart.insert(2, "USB Hub")
print("After inserting USB Hub:", cart)
# Out:
# After inserting USB Hub: ['Laptop', 'Mouse', 'USB Hub', 'Keyboard', 'Monitor', 'Headphones', 'Webcam']

# %%
#Remove "Mouse"
cart.remove("Mouse")
print("After removing Mouse:", cart)
# Out:
# After removing Mouse: ['Laptop', 'USB Hub', 'Keyboard', 'Monitor', 'Headphones', 'Webcam']

# %%
#Remove the last item using pop()
removed_product = cart.pop()
print("Removed product:", removed_product)
print("After pop:", cart)
# Out:
# Removed product: Webcam
# After pop: ['Laptop', 'USB Hub', 'Keyboard', 'Monitor', 'Headphones']

# %%
#Find the index of "Monitor"
monitor_index = cart.index("Monitor")
print("Index of Monitor:", monitor_index)
# Out:
# Index of Monitor: 3

# %%
#Count occurrences of "Laptop"
laptop_count = cart.count("Laptop")
print("Laptop count:", laptop_count)
# Out:
# Laptop count: 1

# %%
#Create a copy of the cart
cart_copy = cart.copy()
print("Cart copy:", cart_copy)
# Out:
# Cart copy: ['Laptop', 'USB Hub', 'Keyboard', 'Monitor', 'Headphones']

# %%
#Reverse the cart
cart.reverse()
print("Reversed cart:", cart)
# Out:
# Reversed cart: ['Headphones', 'Monitor', 'Keyboard', 'USB Hub', 'Laptop']

# %%
#Sort products alphabetically
cart.sort()
print("Sorted cart:", cart)
# Out:
# Sorted cart: ['Headphones', 'Keyboard', 'Laptop', 'Monitor', 'USB Hub']

# %%
#Difference between Shallow copy & Deep copy
print(cart_copy)
cart_copy_deep = cart
print(cart_copy_deep)
# Out:
# ['Laptop', 'USB Hub', 'Keyboard', 'Monitor', 'Headphones']
# ['Headphones', 'Keyboard', 'Laptop', 'Monitor', 'USB Hub']
