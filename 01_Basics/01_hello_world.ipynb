# %% [markdown]
# # Python Basics - Hello World
#
# Welcome to your Python learning journey!

# %%
# Your first Python program
print('Hello, World!')

# %%
# Print your name
name = 'Python Learner'
print(f'Welcome, {name}!')

# %% [markdown]
# ## Exercises
# Try these:
# 1. Change the name variable to your actual name
# 2. Print multiple lines
# 3. Use different print statements
