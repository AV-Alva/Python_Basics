# %%
employee = {"name": "Amit", 
"department": "Engineering",
"skills": {"language": "Python", "database": "PostgreSQL", "cloud": "AWS"},
"salary": 80000}
print(employee)
# Out:
# {'name': 'Amit', 'department': 'Engineering', 'skills': {'language': 'Python', 'database': 'PostgreSQL', 'cloud': 'AWS'}, 'salary': 80000}

# %%
#Print employee name
print("Employee Name:" ,employee["name"])
# Out:
# Employee Name: Amit

# %%
#Print department
print("Employee department:" ,employee["department"])
# Out:
# Employee department: Engineering

# %%
#Print complete skills dictionary
print("Employee Skills list:" ,employee["skills"])
# Out:
# Employee Skills list: {'language': 'Python', 'database': 'PostgreSQL', 'cloud': 'AWS'}

# %%
#Print programming language
print("Employee Programming Skills :" ,employee["skills"]["language"])
# Out:
# Employee Programming Skills : Python

# %%
#Print database
print("Employee Database Skills :" ,employee["skills"]["database"])
# Out:
# Employee Database Skills : PostgreSQL

# %%
#Print cloud technology
print("Employee Cloud Skills :" ,employee["skills"]["cloud"])
# Out:
# Employee Cloud Skills : AWS

# %%
#Change "Python" to "Python + JavaScript"
employee["skills"]["language"] = "Python + JavaScript"
print("Employee Programming Skills :" ,employee["skills"]["language"])
# Out:
# Employee Programming Skills : Python + JavaScript

# %%
#Change salary
print("Old Salary: ", employee["salary"])
employee["salary"]= 100000
print("New Salary: ", employee["salary"])
# Out:
# Old Salary:  80000
# New Salary:  100000

# %%
#Add "experience": 3
employee["experience"] = 3
print("Employee Experience :", employee["experience"])
# Out:
# Employee Experience : 3

# %%
#Add another skill under the skills dictionary
employee["skills"]["framework"] = "React"
print("Updated Skills:", employee["skills"])
# Out:
# Updated Skills: {'language': 'Python + JavaScript', 'database': 'PostgreSQL', 'cloud': 'AWS', 'framework': 'React'}

# %%
#Print complete updated employee dictionary
print("Updated Employee:", employee)
# Out:
# Updated Employee: {'name': 'Amit', 'department': 'Engineering', 'skills': {'language': 'Python + JavaScript', 'database': 'PostgreSQL', 'cloud': 'AWS', 'framework': 'React'}, 'salary': 100000, 'experience': 3}

# %%
#### Accessing Nested Dictionaries

#A **nested dictionary** is a dictionary inside another dictionary.

#To access a nested value, we **chain the keys**:
#employee["skills"]["language"]

#Here:
#* `employee["skills"]` → accesses the `skills` dictionary.
#* `["language"]` → accesses the `language` value inside `skills`.
#* Result → `"Python"`

#**Syntax:**
#dictionary["outer_key"]["inner_key"]

#**Easy way to remember:**

#**First key → Select the inner dictionary**
#**Second key → Select the value inside it**
